# %%
import pandas as pd
import numpy as np
import os
from datetime import datetime

# %%
df = pd.read_csv('../data/race_data/race_data_20251007.csv')
# Out:
# /var/folders/rn/zdwl9_vx4yz5r87jv7jnztdh0000gn/T/ipykernel_3177/3531597614.py:1: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../data/race_data/race_data_20251007.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66472 entries, 0 to 66471
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   RaceIndex         66472 non-null  int64
#  1   Pla.              66472 non-null  object
#  2   Date              66472 non-null  object
#  3   RC/Track/Course   66472 non-null  object
#  4   Dist.             66472 non-null  int64
#  5   G                 66472 non-null  object
#  6   RaceClass         66472 non-null  object
#  7   Dr.               66472 non-null  object
#  8   Rtg.              66472 non-null  object
#  9   Trainer           66472 non-null  object
#  10  Jockey            66423 non-null  object
#  11  LBW               66472 non-null  object
#  12  Win Odds          66472 non-null  object
#  13  Act.Wt.           66472 non-null  int64
#  14  RunningPosition   66472 non-null  object
#  15  Finish Time       66472 non-null  object
#  16  Declar.Horse Wt.  66472 non-null  object
#  17  Gear              66472 non-null  object
#  18  Horse_id          66472 non-null  object
#  19  Origin / Age      66472 non-null  object
#  20  Colour / Sex      66472 non-null  object
#  21  Import type       66472 non-null  object
#  22  Sire              66472 non-null  object
#  23  Dam               66472 non-null  object
#  24  Dam sire          65492 non-null  object
# dtypes: int64(3), object(22)
# memory usage: 12.7+ MB

# %%
df
# Out:
#        RaceIndex Pla.        Date    RC/Track/Course  Dist.   G RaceClass Dr.  \
# 0            238   12  10/12/2023    ST / Turf / "A"   1600   G        G1  10
# 1            623   05  30/04/2023    ST / Turf / "A"   2000   G        G1   7
# 2            240   02  11/12/2022    ST / Turf / "A"   2000   G        G1   6
# 3            402   11  06/02/2021    ST / Turf / "C"   1200   G         5   2
# 4            296   05  26/12/2020  ST / Turf / "A+3"   1200   G         5  14
# ...          ...  ...         ...                ...    ...  ..       ...  ..
# 66467         66   06    04/10/25           ST / AWT   1650  GD         5  11
# 66468         72   07    04/10/25  ST / Turf / "B+2"   1000  GF         3   6
# 66469         69   03    04/10/25  ST / Turf / "B+2"   1400  GF         4   5
# 66470         66   10    04/10/25           ST / AWT   1650  GD         5   6
# 66471         66   03    04/10/25           ST / AWT   1650  GD         5   3
#
#       Rtg.   Trainer  ... Finish Time Declar.Horse Wt.       Gear  Horse_id  \
# 0       --  T Yasuda  ...     1.35.46             1187          H      H811
# 1       --  T Yasuda  ...     2.02.71             1179          H      H811
# 2       --  T Yasuda  ...     2.00.44             1150         --      H811
# 3       18   C H Yip  ...     1.10.66             1045    CP-/TT-      C017
# 4       18   C H Yip  ...     1.10.42             1058      CP/TT      C017
# ...    ...       ...  ...         ...              ...        ...       ...
# 66467   40  K H Ting  ...     1.41.37             1113       B/TT      K069
# 66468   62   C H Yip  ...     0.57.11             1089         TT      K377
# 66469   51  C Fownes  ...     1.21.82             1157         TT      K398
# 66470   37    P C Ng  ...     1.41.52             1201       B/TT      J218
# 66471   32  A S Cruz  ...     1.39.65             1083  H-/PC-/TT      G368
#
#       Origin / Age     Colour / Sex Import type             Sire  \
# 0              JPN      Bay / Horse         VIS       Just A Way
# 1              JPN      Bay / Horse         VIS       Just A Way
# 2              JPN      Bay / Horse         VIS       Just A Way
# 3              AUS  Brown / Gelding         PPG    Smart Missile
# 4              AUS  Brown / Gelding         PPG    Smart Missile
# ...            ...              ...         ...              ...
# 66467      AUS / 4    Bay / Gelding         PPG       Deep Field
# 66468       GB / 3    Bay / Gelding         PPG       Land Force
# 66469       NZ / 4    Bay / Gelding         PPG        Ardrossan
# 66470      AUS / 5    Bay / Gelding         PPG       Deep Field
# 66471       FR / 6    Bay / Gelding          PP  Wootton Bassett
#
#                   Dam           Dam sire
# 0           Epic Love            Dansili
# 1           Epic Love            Dansili
# 2           Epic Love            Dansili
# 3          Pyrography            Danzero
# 4          Pyrography            Danzero
# ...               ...                ...
# 66467        Nakataan             Zabeel
# 66468  Phantom Spirit  Invincible Spirit
# 66469     Dolce Amore            Sebring
# 66470   Alberton Park         Thorn Park
# 66471     Mezzo Mezzo       Mount Nelson
#
# [66472 rows x 25 columns]

# %% [markdown]
# # Basic Cleaning

# %% [markdown]
# ## utility function

# %%
# combine race index with date to form new index
def combine_index_date(df, col1, col2, new_col):

    df['race_index'] = df[col1].astype(str) + df[col2].dt.strftime('%d%m%y')

    df = df.drop(columns = ['RaceIndex'])

    return df

# %%
# convert to new race index format
def convert_year(date_str):
    day, month, year = date_str.split('/')

    if len(year) == 4:
        year = year[2:]

    date = f'{day}/{month}/{year}'
    
    return pd.to_datetime(date, format = '%d/%m/%y')

# %%
# clean RC, Track, Course
def clean_rc_track_course(text):
    parts = str(text).split('/')

    if len(parts) < 3:
        rc = parts[0].strip()
        track = parts[1].strip()
        course = None
    
    else:
        rc, track, course = parts[0].strip(), parts[1].strip(), parts[2].strip().replace('"', '')

    return rc, track, course

# %%
# clean origin, age
def clean_origin_age(text):
    parts = str(text).split('/')

    if len(parts) < 2:
        origin = parts[0].strip()
        age = None
    
    else:
        origin = parts[0].strip()
        age = parts[1].strip()
    
    return origin, age

# %%
# clean colour, sex
def clean_colour_sex(text):
    parts = str(text).split('/')

    colour = parts[0].strip()
    sex = parts[-1].strip()

    return colour, sex

# %% [markdown]
# ## Workflow

# %%
exclude = ['WV', 'WV-A', 'WX', 'WX-A', 'WXNR']
df = df[~df['Pla.'].isin(exclude)].copy()

# %%
df['Date'] = df['Date'].apply(convert_year)

# %%
df = combine_index_date(df, 'RaceIndex', 'Date', 'race_index')

# %%
# exponential decay for top finishers
df['target'] = df.groupby('race_index')['Pla.'].transform(
    lambda x: x.apply(lambda place: np.exp(-(int(place)-1)/2) if str(place).isdigit() and int(place) <= 4 else 0)
)

# %%
df[['rc', 'track', 'course']] = df['RC/Track/Course'].apply(clean_rc_track_course).apply(pd.Series)
df = df.drop(columns=['RC/Track/Course'])

# %%
df[['origin', 'age']] = df['Origin / Age'].apply(clean_origin_age).apply(pd.Series)
df = df.drop(columns = ['Origin / Age'])

# %%
# clean colour, sex
df[['colour', 'sex']] = df['Colour / Sex'].apply(clean_colour_sex).apply(pd.Series)
df = df.drop(columns = ['Colour / Sex'])

# %%
# clean rating
df['Rtg.'] = pd.to_numeric(df['Rtg.'], errors = 'coerce')

# %%
# rename columns
df = df.rename(columns = {'Dr.' : 'gate_position', 'G' : 'track_condition'})

# %%
df = df[['Date', 'race_index', 'RaceClass', 'rc', 'track', 'course', 'Dist.', 'track_condition', 'Horse_id', 'Declar.Horse Wt.', 'Act.Wt.', 'gate_position', 'Rtg.', 'age', 'colour', 'sex', 'origin', 'Import type', 'Trainer', 'Jockey', 'Sire', 'Dam', 'Dam sire', 'Finish Time', 'Gear', 'target']]

# %%
for col in ['race_index', 'Declar.Horse Wt.', 'age']:
    df[col] = pd.to_numeric(df[col], errors = 'coerce')

# %%
df = df[df['Date'] > pd.to_datetime('04/09/20', format = '%d/%m/%y')]

# %%
df
# Out:
#             Date  race_index RaceClass  rc track course  Dist.  \
# 0     2023-12-10   238101223        G1  ST  Turf      A   1600
# 1     2023-04-30   623300423        G1  ST  Turf      A   2000
# 2     2022-12-11   240111222        G1  ST  Turf      A   2000
# 3     2021-02-06   402060221         5  ST  Turf      C   1200
# 4     2020-12-26   296261220         5  ST  Turf    A+3   1200
# ...          ...         ...       ...  ..   ...    ...    ...
# 66467 2025-10-04    66041025         5  ST   AWT   None   1650
# 66468 2025-10-04    72041025         3  ST  Turf    B+2   1000
# 66469 2025-10-04    69041025         4  ST  Turf    B+2   1400
# 66470 2025-10-04    66041025         5  ST   AWT   None   1650
# 66471 2025-10-04    66041025         5  ST   AWT   None   1650
#
#       track_condition Horse_id  Declar.Horse Wt.  ...  origin Import type  \
# 0                   G     H811              1187  ...     JPN         VIS
# 1                   G     H811              1179  ...     JPN         VIS
# 2                   G     H811              1150  ...     JPN         VIS
# 3                   G     C017              1045  ...     AUS         PPG
# 4                   G     C017              1058  ...     AUS         PPG
# ...               ...      ...               ...  ...     ...         ...
# 66467              GD     K069              1113  ...     AUS         PPG
# 66468              GF     K377              1089  ...      GB         PPG
# 66469              GF     K398              1157  ...      NZ         PPG
# 66470              GD     J218              1201  ...     AUS         PPG
# 66471              GD     G368              1083  ...      FR          PP
#
#         Trainer      Jockey             Sire             Dam  \
# 0      T Yasuda  Y Kitamura       Just A Way       Epic Love
# 1      T Yasuda      C Y Ho       Just A Way       Epic Love
# 2      T Yasuda  Y Kitamura       Just A Way       Epic Love
# 3       C H Yip      C Wong    Smart Missile      Pyrography
# 4       C H Yip    M F Poon    Smart Missile      Pyrography
# ...         ...         ...              ...             ...
# 66467  K H Ting    P N Wong       Deep Field        Nakataan
# 66468   C H Yip   Y L Chung       Land Force  Phantom Spirit
# 66469  C Fownes  L Ferraris        Ardrossan     Dolce Amore
# 66470    P C Ng    K Teetan       Deep Field   Alberton Park
# 66471  A S Cruz   Y L Chung  Wootton Bassett     Mezzo Mezzo
#
#                 Dam sire Finish Time       Gear    target
# 0                Dansili     1.35.46          H  0.000000
# 1                Dansili     2.02.71          H  0.000000
# 2                Dansili     2.00.44         --  0.606531
# 3                Danzero     1.10.66    CP-/TT-  0.000000
# 4                Danzero     1.10.42      CP/TT  0.000000
# ...                  ...         ...        ...       ...
# 66467             Zabeel     1.41.37       B/TT  0.000000
# 66468  Invincible Spirit     0.57.11         TT  0.000000
# 66469            Sebring     1.21.82         TT  0.367879
# 66470         Thorn Park     1.41.52       B/TT  0.000000
# 66471       Mount Nelson     1.39.65  H-/PC-/TT  0.367879
#
# [51485 rows x 26 columns]

# %% [markdown]
# # Feature engineering

# %%
df = df.sort_values(['Horse_id', 'Date'])

n = 3

df['recent_3_win_rate_horse'] = (
    df.groupby('Horse_id')['target']
    .transform(lambda x: x.shift().rolling(window=n, min_periods = 3).mean())
)

# %%
df = df.sort_values(['Jockey', 'Date'])

df['recent_3_win_rate_jockey'] = (
    df.groupby('Jockey')['target']
    .transform(lambda x: x.shift().rolling(window=n, min_periods = 3).mean())
)

# %%
# Expand your rolling statistics beyond just win rate
df['recent_5_avg_finish_pos'] = (
    df.groupby('Horse_id')['target']
    .transform(lambda x: x.shift().rolling(window=5, min_periods=2).mean())
)

df['recent_3_consistency'] = (
    df.groupby('Horse_id')['target']
    .transform(lambda x: x.shift().rolling(window=3, min_periods=2).std())
)

# Jockey-Trainer combination performance
df['jockey_trainer_combo_rate'] = (
    df.groupby(['Jockey', 'Trainer'])['target']
    .transform(lambda x: x.shift().expanding(min_periods=5).mean())
)

# Horse performance on specific track/distance combinations
df['horse_track_distance_rate'] = (
    df.groupby(['Horse_id', 'track', 'Dist.'])['target']
    .transform(lambda x: x.shift().expanding(min_periods=2).mean())
)

# %%
overall_mean_win_rate = np.mean(df['target'] == 4)
df['recent_3_win_rate_horse'] = df['recent_3_win_rate_horse'].fillna(overall_mean_win_rate)
df['recent_3_win_rate_jockey'] = df['recent_3_win_rate_jockey'].fillna(overall_mean_win_rate)
df['recent_5_avg_finish_pos'] = df['recent_5_avg_finish_pos'].fillna(overall_mean_win_rate)
df['recent_3_consistency'] = df['recent_3_consistency'].fillna(overall_mean_win_rate)
df['jockey_trainer_combo_rate'] = df['jockey_trainer_combo_rate'].fillna(overall_mean_win_rate)
df['horse_track_distance_rate'] = df['horse_track_distance_rate'].fillna(overall_mean_win_rate)

# %%
df.sort_values('race_index', ascending=False)
# Out:
#             Date  race_index RaceClass  rc track course  Dist.  \
# 61481 2025-07-16   847160725         3  HV  Turf      B   1200
# 56454 2025-07-16   847160725         3  HV  Turf      B   1200
# 63166 2025-07-16   847160725         3  HV  Turf      B   1200
# 58494 2025-07-16   847160725         3  HV  Turf      B   1200
# 15631 2025-07-16   847160725         3  HV  Turf      B   1200
# ...          ...         ...       ...  ..   ...    ...    ...
# 42204 2021-09-05     1050921         5  ST  Turf      A   1400
# 13160 2021-09-05     1050921         5  ST  Turf      A   1400
# 8400  2021-09-05     1050921         5  ST  Turf      A   1400
# 7835  2021-09-05     1050921         5  ST  Turf      A   1400
# 10133 2021-09-05     1050921         5  ST  Turf      A   1400
#
#       track_condition Horse_id  Declar.Horse Wt.  ...          Dam sire  \
# 61481              GF     H396              1056  ...      He's A Decoy
# 56454              GF     J537              1176  ...           Choisir
# 63166              GF     J401              1120  ...        Bernardini
# 58494              GF     J393              1035  ...             Nayef
# 15631              GF     G016              1081  ...            Keeper
# ...               ...      ...               ...  ...               ...
# 42204               G     A217              1091  ...            Anabaa
# 13160               G     B288              1048  ...    High Chaparral
# 8400                G     D190              1054  ...      Green Desert
# 7835                G     D307               984  ...  Cadeaux Genereux
# 10133               G     B394              1146  ...    General Nediym
#
#       Finish Time  Gear    target recent_3_win_rate_horse  \
# 61481     1.09.37  H/XB  0.000000                0.074377
# 56454     1.09.88    CP  0.000000                0.074377
# 63166     1.09.53    CP  0.000000                0.455960
# 58494     1.09.22    TT  0.367879                0.535510
# 15631     1.09.67    TT  0.000000                0.000000
# ...           ...   ...       ...                     ...
# 42204     1.23.22     B  0.000000                0.000000
# 13160     1.22.66    --  1.000000                0.122626
# 8400      1.24.43    --  0.000000                0.000000
# 7835      1.22.76  H/TT  0.606531                0.000000
# 10133     1.23.32    TT  0.000000                0.000000
#
#       recent_3_win_rate_jockey recent_5_avg_finish_pos recent_3_consistency  \
# 61481                 0.407710                0.365932             0.128824
# 56454                 0.407710                0.244626             0.128824
# 63166                 0.658137                0.000000             0.000000
# 58494                 0.202177                0.000000             0.000000
# 15631                 0.000000                0.044626             0.000000
# ...                        ...                     ...                  ...
# 42204                 0.000000                0.273576             0.000000
# 13160                 0.000000                0.118202             0.212395
# 8400                  0.333333                0.000000             0.000000
# 7835                  0.407710                0.394882             0.503769
# 10133                 0.000000                0.000000             0.000000
#
#       jockey_trainer_combo_rate horse_track_distance_rate
# 61481                  0.194644                  0.279518
# 56454                  0.174437                  0.305783
# 63166                  0.084676                  0.000000
# 58494                  0.112289                  0.000000
# 15631                  0.170994                  0.339009
# ...                         ...                       ...
# 42204                  0.099228                  0.000000
# 13160                  0.123311                  0.116306
# 8400                   0.061043                  0.000000
# 7835                   0.270866                  0.000000
# 10133                  0.152472                  0.000000
#
# [51485 rows x 32 columns]

# %%
current_time = datetime.now().strftime('%Y%m%d')

output_dir = '../data/'
output_path = os.path.join(output_dir, f'cleaned_data_{current_time}.csv')

os.makedirs(output_dir, exist_ok = True)

df.to_csv(output_path, index = False)
