# %%
import pandas as pd
import numpy as np
import os

# %%
df = pd.read_csv('../data/race_data/race_data.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65523 entries, 0 to 65522
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   RaceIndex         65523 non-null  int64
#  1   Pla.              65523 non-null  object
#  2   Date              65523 non-null  object
#  3   RC/Track/Course   65523 non-null  object
#  4   Dist.             65523 non-null  int64
#  5   G                 65523 non-null  object
#  6   RaceClass         65523 non-null  object
#  7   Dr.               65523 non-null  object
#  8   Rtg.              65523 non-null  object
#  9   Trainer           65523 non-null  object
#  10  Jockey            65474 non-null  object
#  11  LBW               65523 non-null  object
#  12  Win Odds          65523 non-null  object
#  13  Act.Wt.           65523 non-null  int64
#  14  RunningPosition   65523 non-null  object
#  15  Finish Time       65523 non-null  object
#  16  Declar.Horse Wt.  65523 non-null  object
#  17  Gear              65523 non-null  object
#  18  Horse_id          65523 non-null  object
#  19  Origin / Age      65523 non-null  object
#  20  Colour / Sex      65523 non-null  object
#  21  Import type       65523 non-null  object
#  22  Sire              65523 non-null  object
#  23  Dam               65523 non-null  object
#  24  Dam sire          64551 non-null  object
# dtypes: int64(3), object(22)
# memory usage: 12.5+ MB

# %%
df
# Out:
#        RaceIndex Pla.        Date    RC/Track/Course  Dist.   G RaceClass Dr.  \
# 0            238   12  10/12/2023    ST / Turf / "A"   1600   G        G1  10
# 1            623   05  30/04/2023    ST / Turf / "A"   2000   G        G1   7
# 2            240   02  11/12/2022    ST / Turf / "A"   2000   G        G1   6
# 3            402   11  06/02/2021    ST / Turf / "C"   1200   G         5   2
# 4            296   05  26/12/2020  ST / Turf / "A+3"   1200   G         5  14
# ...          ...  ...         ...                ...    ...  ..       ...  ..
# 65518        278   03    23/12/23    ST / Turf / "C"   1400   G         3  11
# 65519        240   02    10/12/23    ST / Turf / "A"   1200   G         3  10
# 65520        185   02    19/11/23  ST / Turf / "B+2"   1200  GF         3   6
# 65521        801   06    01/07/25    ST / Turf / "C"   1200   G         4  11
# 65522        738   03    08/06/25    ST / Turf / "C"   1200  GF         4   4
#
#       Rtg.    Trainer  ... Finish Time Declar.Horse Wt.     Gear  Horse_id  \
# 0       --   T Yasuda  ...     1.35.46             1187        H      H811
# 1       --   T Yasuda  ...     2.02.71             1179        H      H811
# 2       --   T Yasuda  ...     2.00.44             1150       --      H811
# 3       18    C H Yip  ...     1.10.66             1045  CP-/TT-      C017
# 4       18    C H Yip  ...     1.10.42             1058    CP/TT      C017
# ...    ...        ...  ...         ...              ...      ...       ...
# 65518   68   C Fownes  ...     1.22.88             1152       --      H459
# 65519   68   C Fownes  ...     1.09.52             1153       --      H459
# 65520   68   C Fownes  ...     1.08.94             1155       --      H459
# 65521   53  M Newnham  ...     1.10.15             1127       B1      K334
# 65522   52  M Newnham  ...     1.08.75             1125       --      K334
#
#       Origin / Age     Colour / Sex Import type           Sire         Dam  \
# 0              JPN      Bay / Horse         VIS     Just A Way   Epic Love
# 1              JPN      Bay / Horse         VIS     Just A Way   Epic Love
# 2              JPN      Bay / Horse         VIS     Just A Way   Epic Love
# 3              AUS  Brown / Gelding         PPG  Smart Missile  Pyrography
# 4              AUS  Brown / Gelding         PPG  Smart Missile  Pyrography
# ...            ...              ...         ...            ...         ...
# 65518      AUS / 6    Bay / Gelding          PP      Impending   Isola Blu
# 65519      AUS / 6    Bay / Gelding          PP      Impending   Isola Blu
# 65520      AUS / 6    Bay / Gelding          PP      Impending   Isola Blu
# 65521      AUS / 4   Grey / Gelding         PPG    Street Boss    Varanasi
# 65522      AUS / 4   Grey / Gelding         PPG    Street Boss    Varanasi
#
#               Dam sire
# 0              Dansili
# 1              Dansili
# 2              Dansili
# 3              Danzero
# 4              Danzero
# ...                ...
# 65518      Blackfriars
# 65519      Blackfriars
# 65520      Blackfriars
# 65521  Encosta de Lago
# 65522  Encosta de Lago
#
# [65523 rows x 25 columns]

# %% [markdown]
# # Basic Cleaning

# %% [markdown]
# ## utility function

# %%
# combine race index with date to form new index
def combine_index_date(df, col1, col2, new_col):

    df['race_index'] = df[col1].astype(str) + df[col2].dt.strftime('%d%m%y')

    df = df.drop(columns = ['RaceIndex'])

    return df

# %%
# convert to new race index format
def convert_year(date_str):
    day, month, year = date_str.split('/')

    if len(year) == 4:
        year = year[2:]

    date = f'{day}/{month}/{year}'
    
    return pd.to_datetime(date, format = '%d/%m/%y')

# %%
# clean RC, Track, Course
def clean_rc_track_course(text):
    parts = str(text).split('/')

    if len(parts) < 3:
        rc = parts[0].strip()
        track = parts[1].strip()
        course = None
    
    else:
        rc, track, course = parts[0].strip(), parts[1].strip(), parts[2].strip().replace('"', '')

    return rc, track, course

# %%
# clean origin, age
def clean_origin_age(text):
    parts = str(text).split('/')

    if len(parts) < 2:
        origin = parts[0].strip()
        age = None
    
    else:
        origin = parts[0].strip()
        age = parts[1].strip()
    
    return origin, age

# %%
# clean colour, sex
def clean_colour_sex(text):
    parts = str(text).split('/')

    colour = parts[0].strip()
    sex = parts[-1].strip()

    return colour, sex

# %% [markdown]
# ## Workflow

# %%
exclude = ['WV', 'WV-A', 'WX', 'WX-A', 'WXNR']
df = df[~df['Pla.'].isin(exclude)].copy()

# %%
df['Date'] = df['Date'].apply(convert_year)

# %%
df = combine_index_date(df, 'RaceIndex', 'Date', 'race_index')

# %%
# exponential decay for top finishers
df['target'] = df.groupby('race_index')['Pla.'].transform(
    lambda x: x.apply(lambda place: np.exp(-(int(place)-1)/2) if str(place).isdigit() and int(place) <= 4 else 0)
)

# %%
df[['rc', 'track', 'course']] = df['RC/Track/Course'].apply(clean_rc_track_course).apply(pd.Series)
df = df.drop(columns=['RC/Track/Course'])

# %%
df[['origin', 'age']] = df['Origin / Age'].apply(clean_origin_age).apply(pd.Series)
df = df.drop(columns = ['Origin / Age'])

# %%
# clean colour, sex
df[['colour', 'sex']] = df['Colour / Sex'].apply(clean_colour_sex).apply(pd.Series)
df = df.drop(columns = ['Colour / Sex'])

# %%
# clean rating
df['Rtg.'] = pd.to_numeric(df['Rtg.'], errors = 'coerce')

# %%
# rename columns
df = df.rename(columns = {'Dr.' : 'gate_position', 'G' : 'track_condition'})

# %%
df = df[['Date', 'race_index', 'RaceClass', 'rc', 'track', 'course', 'Dist.', 'track_condition', 'Horse_id', 'Declar.Horse Wt.', 'Act.Wt.', 'gate_position', 'Rtg.', 'age', 'colour', 'sex', 'origin', 'Import type', 'Trainer', 'Jockey', 'Sire', 'Dam', 'Dam sire', 'Finish Time', 'Gear', 'target']]

# %%
for col in ['race_index', 'Declar.Horse Wt.', 'age']:
    df[col] = pd.to_numeric(df[col], errors = 'coerce')

# %%
df = df[df['Date'] > pd.to_datetime('04/09/20', format = '%d/%m/%y')]

# %%
df
# Out:
#             Date  race_index RaceClass  rc track course  Dist.  \
# 0     2023-12-10   238101223        G1  ST  Turf      A   1600
# 1     2023-04-30   623300423        G1  ST  Turf      A   2000
# 2     2022-12-11   240111222        G1  ST  Turf      A   2000
# 3     2021-02-06   402060221         5  ST  Turf      C   1200
# 4     2020-12-26   296261220         5  ST  Turf    A+3   1200
# ...          ...         ...       ...  ..   ...    ...    ...
# 65518 2023-12-23   278231223         3  ST  Turf      C   1400
# 65519 2023-12-10   240101223         3  ST  Turf      A   1200
# 65520 2023-11-19   185191123         3  ST  Turf    B+2   1200
# 65521 2025-07-01   801010725         4  ST  Turf      C   1200
# 65522 2025-06-08   738080625         4  ST  Turf      C   1200
#
#       track_condition Horse_id  Declar.Horse Wt.  ...  origin Import type  \
# 0                   G     H811              1187  ...     JPN         VIS
# 1                   G     H811              1179  ...     JPN         VIS
# 2                   G     H811              1150  ...     JPN         VIS
# 3                   G     C017              1045  ...     AUS         PPG
# 4                   G     C017              1058  ...     AUS         PPG
# ...               ...      ...               ...  ...     ...         ...
# 65518               G     H459              1152  ...     AUS          PP
# 65519               G     H459              1153  ...     AUS          PP
# 65520              GF     H459              1155  ...     AUS          PP
# 65521               G     K334              1127  ...     AUS         PPG
# 65522              GF     K334              1125  ...     AUS         PPG
#
#          Trainer      Jockey           Sire         Dam         Dam sire  \
# 0       T Yasuda  Y Kitamura     Just A Way   Epic Love          Dansili
# 1       T Yasuda      C Y Ho     Just A Way   Epic Love          Dansili
# 2       T Yasuda  Y Kitamura     Just A Way   Epic Love          Dansili
# 3        C H Yip      C Wong  Smart Missile  Pyrography          Danzero
# 4        C H Yip    M F Poon  Smart Missile  Pyrography          Danzero
# ...          ...         ...            ...         ...              ...
# 65518   C Fownes      C Y Ho      Impending   Isola Blu      Blackfriars
# 65519   C Fownes      C Y Ho      Impending   Isola Blu      Blackfriars
# 65520   C Fownes      C Y Ho      Impending   Isola Blu      Blackfriars
# 65521  M Newnham    Z Purton    Street Boss    Varanasi  Encosta de Lago
# 65522  M Newnham    Z Purton    Street Boss    Varanasi  Encosta de Lago
#
#       Finish Time     Gear    target
# 0         1.35.46        H  0.000000
# 1         2.02.71        H  0.000000
# 2         2.00.44       --  0.606531
# 3         1.10.66  CP-/TT-  0.000000
# 4         1.10.42    CP/TT  0.000000
# ...           ...      ...       ...
# 65518     1.22.88       --  0.367879
# 65519     1.09.52       --  0.606531
# 65520     1.08.94       --  0.606531
# 65521     1.10.15       B1  0.000000
# 65522     1.08.75       --  0.367879
#
# [50544 rows x 26 columns]

# %% [markdown]
# # Feature engineering

# %%
df = df.sort_values(['Horse_id', 'Date'])

n = 3

df['recent_3_win_rate_horse'] = (
    df.groupby('Horse_id')['target']
    .transform(lambda x: x.shift().rolling(window=n, min_periods = 3).apply(lambda y: np.mean(y == 4),raw = True))
)

# %%
df = df.sort_values(['Jockey', 'Date'])

df['recent_3_win_rate_jockey'] = (
    df.groupby('Jockey')['target']
    .transform(lambda x: x.shift().rolling(window=n, min_periods = 3).apply(lambda y: np.mean(y == 4),raw = True))
)

# %%
# Expand your rolling statistics beyond just win rate
df['recent_5_avg_finish_pos'] = (
    df.groupby('Horse_id')['target']
    .transform(lambda x: x.shift().rolling(window=5, min_periods=2).mean())
)

df['recent_3_consistency'] = (
    df.groupby('Horse_id')['target']
    .transform(lambda x: x.shift().rolling(window=3, min_periods=2).std())
)

# Jockey-Trainer combination performance
df['jockey_trainer_combo_rate'] = (
    df.groupby(['Jockey', 'Trainer'])['target']
    .transform(lambda x: x.shift().expanding(min_periods=5).mean())
)

# Horse performance on specific track/distance combinations
df['horse_track_distance_rate'] = (
    df.groupby(['Horse_id', 'track', 'Dist.'])['target']
    .transform(lambda x: x.shift().expanding(min_periods=2).mean())
)

# %%
overall_mean_win_rate = np.mean(df['target'] == 4)
df['recent_3_win_rate_horse'] = df['recent_3_win_rate_horse'].fillna(overall_mean_win_rate)
df['recent_3_win_rate_jockey'] = df['recent_3_win_rate_jockey'].fillna(overall_mean_win_rate)
df['recent_5_avg_finish_pos'] = df['recent_5_avg_finish_pos'].fillna(overall_mean_win_rate)
df['recent_3_consistency'] = df['recent_3_consistency'].fillna(overall_mean_win_rate)
df['jockey_trainer_combo_rate'] = df['jockey_trainer_combo_rate'].fillna(overall_mean_win_rate)
df['horse_track_distance_rate'] = df['horse_track_distance_rate'].fillna(overall_mean_win_rate)

# %%
df.sort_values('race_index', ascending=False)
# Out:
#             Date  race_index RaceClass  rc track course  Dist.  \
# 61481 2025-07-16   847160725         3  HV  Turf      B   1200
# 58594 2025-07-16   847160725         3  HV  Turf      B   1200
# 58655 2025-07-16   847160725         3  HV  Turf      B   1200
# 59032 2025-07-16   847160725         3  HV  Turf      B   1200
# 62772 2025-07-16   847160725         3  HV  Turf      B   1200
# ...          ...         ...       ...  ..   ...    ...    ...
# 8400  2021-09-05     1050921         5  ST  Turf      A   1400
# 43529 2021-09-05     1050921         5  ST  Turf      A   1400
# 16206 2021-09-05     1050921         5  ST  Turf      A   1400
# 1071  2021-09-05     1050921         5  ST  Turf      A   1400
# 26064 2021-09-05     1050921         5  ST  Turf      A   1400
#
#       track_condition Horse_id  Declar.Horse Wt.  ...           Dam sire  \
# 61481              GF     H396              1056  ...       He's A Decoy
# 58594              GF     K258              1101  ...            Kingman
# 58655              GF     J394              1104  ...             Diktat
# 59032              GF     J317              1178  ...           Foreplay
# 62772              GF     J396              1084  ...  Duke Of Marmalade
# ...               ...      ...               ...  ...                ...
# 8400                G     D190              1054  ...       Green Desert
# 43529               G     E104              1063  ...           Danehill
# 16206               G     D502              1191  ...       Kitten's Joy
# 1071                G     E214              1063  ...              Marju
# 26064               G     D303              1238  ...             Dubawi
#
#       Finish Time  Gear   target recent_3_win_rate_horse  \
# 61481     1.09.37  H/XB  0.00000                     0.0
# 58594     1.09.13    --  1.00000                     0.0
# 58655     1.10.26    TT  0.00000                     0.0
# 59032     1.09.48     B  0.00000                     0.0
# 62772     1.09.26    TT  0.22313                     0.0
# ...           ...   ...      ...                     ...
# 8400      1.24.43    --  0.00000                     0.0
# 43529     1.22.97    XB  0.00000                     0.0
# 16206     1.24.13    TT  0.00000                     0.0
# 1071      1.25.05  B/TT  0.00000                     0.0
# 26064     1.22.87    --  0.22313                     0.0
#
#       recent_3_win_rate_jockey recent_5_avg_finish_pos recent_3_consistency  \
# 61481                      0.0                0.365932             0.128824
# 58594                      0.0                0.000000             0.000000
# 58655                      0.0                0.000000             0.000000
# 59032                      0.0                0.473576             0.364955
# 62772                      0.0                0.273576             0.577350
# ...                        ...                     ...                  ...
# 8400                       0.0                0.000000             0.000000
# 43529                      0.0                0.444626             0.577350
# 16206                      0.0                0.091970             0.212395
# 1071                       0.0                0.111565             0.157777
# 26064                      0.0                0.000000             0.000000
#
#       jockey_trainer_combo_rate horse_track_distance_rate
# 61481                  0.194644                  0.279518
# 58594                  0.189579                  0.000000
# 58655                  0.000000                  0.000000
# 59032                  0.379739                  0.597441
# 62772                  0.124638                  0.341970
# ...                         ...                       ...
# 8400                   0.061043                  0.000000
# 43529                  0.087333                  0.000000
# 16206                  0.389762                  0.183940
# 1071                   0.219613                  0.000000
# 26064                  0.087366                  0.000000
#
# [50544 rows x 32 columns]

# %%
output_dir = '../data/'
output_path = os.path.join(output_dir, 'cleaned_data_new.csv')

os.makedirs(output_dir, exist_ok = True)

df.to_csv(output_path, index = False)
